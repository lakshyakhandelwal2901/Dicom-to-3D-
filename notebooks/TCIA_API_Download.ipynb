# %% [markdown]
# # TCIA API Quickstart (tcia_utils)
#
# Steps:
# 1. Install dependencies (tcia_utils).
# 2. List collections.
# 3. Filter series (collection, modality=CT, body part).
# 4. Download one series to `data/tcia_downloads/`.
# 5. Summarize downloaded files.
#
# Notes:
# - Many collections are public; some require TCIA login/API key.
# - LIDC-IDRI is public and works without auth.

# %%
# Install if missing (idempotent)
try:
    import tcia_utils  # noqa: F401
except ImportError:
    import sys, subprocess
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'tcia_utils'])
# Out:
# Collecting tcia_utils
#   Using cached tcia_utils-3.2.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting bs4 (from tcia_utils)
#   Using cached bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: ipython in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from tcia_utils) (9.9.0)
# Collecting pandas (from tcia_utils)
#   Using cached pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting plotly (from tcia_utils)
#   Using cached plotly-6.5.2-py3-none-any.whl.metadata (8.5 kB)
# Collecting requests (from tcia_utils)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting tqdm (from tcia_utils)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting unidecode (from tcia_utils)
#   Using cached Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Collecting beautifulsoup4 (from bs4->tcia_utils)
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->bs4->tcia_utils)
#   Using cached soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4->bs4->tcia_utils)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: decorator>=4.3.2 in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from ipython->tcia_utils) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from ipython->tcia_utils) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from ipython->tcia_utils) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from ipython->tcia_utils) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from ipython->tcia_utils) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from ipython->tcia_utils) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from ipython->tcia_utils) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from ipython->tcia_utils) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from ipython->tcia_utils) (5.14.3)
# Requirement already satisfied: wcwidth in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->tcia_utils) (0.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from jedi>=0.18.1->ipython->tcia_utils) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython->tcia_utils) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->tcia_utils) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->tcia_utils) (3.0.1)
# Requirement already satisfied: pure-eval in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->tcia_utils) (0.2.3)
# Collecting numpy>=1.26.0 (from pandas->tcia_utils)
#   Using cached numpy-2.4.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from pandas->tcia_utils) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->tcia_utils) (1.17.0)
# Collecting narwhals>=1.15.1 (from plotly->tcia_utils)
#   Using cached narwhals-2.15.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /workspaces/Dicom-to-3D-/.venv/lib/python3.12/site-packages (from plotly->tcia_utils) (26.0)
# Collecting charset_normalizer<4,>=2 (from requests->tcia_utils)
#   Using cached charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests->tcia_utils)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->tcia_utils)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests->tcia_utils)
#   Using cached certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Using cached tcia_utils-3.2.1-py3-none-any.whl (39 kB)
# Using cached bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
# Using cached numpy-2.4.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
# Using cached plotly-6.5.2-py3-none-any.whl (9.9 MB)
# Using cached narwhals-2.15.0-py3-none-any.whl (432 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading certifi-2026.1.4-py3-none-any.whl (152 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached Unidecode-1.4.0-py3-none-any.whl (235 kB)
# Installing collected packages: urllib3, unidecode, typing-extensions, tqdm, soupsieve, numpy, narwhals, idna, charset_normalizer, certifi, requests, plotly, pandas, beautifulsoup4, bs4, tcia_utils
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [tcia_utils]6 [beautifulsoup4]zer]
# Successfully installed beautifulsoup4-4.14.3 bs4-0.0.2 certifi-2026.1.4 charset_normalizer-3.4.4 idna-3.11 narwhals-2.15.0 numpy-2.4.1 pandas-3.0.0 plotly-6.5.2 requests-2.32.5 soupsieve-2.8.3 tcia_utils-3.2.1 tqdm-4.67.1 typing-extensions-4.15.0 unidecode-1.4.0 urllib3-2.6.3

# %%
from tcia_utils import nbia
import os, pprint

# %% [markdown]
# ## 1) List collections
# Shows available collections via NBIA.

# %%
collections = nbia.get_collections()
print(f'Total collections: {len(collections)}')
collections.head()

# %% [markdown]
# ## 2) Filter series (collection, modality, body part)
# Using LIDC-IDRI (public lung CT) as example.

# %%
collection = 'LIDC-IDRI'
series_df = nbia.get_series(Collection=collection, Modality='CT', BodyPartExamined='CHEST')
print(f'Series found: {len(series_df)}')
series_df.head()

# %% [markdown]
# ## 3) Pick one SeriesInstanceUID
# Select the first one (customize as needed).

# %%
if series_df.empty:
    raise SystemExit('No series found for the given filters; adjust collection/modality/body part.')
series_uid = series_df.iloc[0]['SeriesInstanceUID']
print('Selected SeriesInstanceUID:', series_uid)

# %% [markdown]
# ## 4) Download the series
# Files will be saved under `data/tcia_downloads/<SeriesInstanceUID>/`.

# %%
output_root = '/workspaces/Dicom-to-3D-/data/tcia_downloads'
os.makedirs(output_root, exist_ok=True)
target_dir = os.path.join(output_root, series_uid)
os.makedirs(target_dir, exist_ok=True)

nbia.download_series(SeriesInstanceUID=series_uid, path=target_dir, includePHI=False)
print('Download complete ->', target_dir)

# %% [markdown]
# ## 5) Summarize downloaded files

# %%
file_count = 0
for root, _, files in os.walk(target_dir):
    file_count += len([f for f in files if f.lower().endswith('.dcm')])
print(f'DICOM files downloaded: {file_count}')
# Show a few filenames
sample_files = []
for root, _, files in os.walk(target_dir):
    for f in files:
        if f.lower().endswith('.dcm'):
            sample_files.append(os.path.join(root, f))
    if len(sample_files) >= 5:
        break
print('Sample files:')
pprint.pp(sample_files[:5])
